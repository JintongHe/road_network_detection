# %% [markdown]
# # 语义分割模型使用实例——道路分割

# %% [markdown]
# 首先导入必要的包

# %%
import sys
sys.path.append('../dataset_preparation')
sys.path.append('../training')
sys.path.append('../inference')
import linestrip_to_mask, split_image_mask_train, split_train_val_test, visualize_mask
import train
import inference, skeleton
import requests
import zipfile
import os
import gdown

# %% [markdown]
# ## 1.数据准备

# %% [markdown]
# 运行以下代码下载数据集

# %%
url = 'https://drive.google.com/file/d/1oFHu6KEzEHMrnKwSJ8iye4Ggp1BZ-czD/view?usp=sharing'
output_path = 'road_network_detection.zip'
gdown.download(url, output_path, quiet=False, fuzzy=True)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1oFHu6KEzEHMrnKwSJ8iye4Ggp1BZ-czD
# From (redirected): https://drive.google.com/uc?id=1oFHu6KEzEHMrnKwSJ8iye4Ggp1BZ-czD&confirm=t&uuid=d02a2755-5983-4e97-89c2-2b0bc463ef4e
# To: /home/zkxq/project/hjt/road_network_detection/examples/road_network_detection.zip
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 3.82G/3.82G [01:19<00:00, 48.0MB/s]
# 'road_network_detection.zip'

# %%
! mkdir dataset
! mv road_network_detection.zip dataset
! unzip dataset/road_network_detection.zip

# %% [markdown]
# 运行linestrip_to_mask程序，可将geojson格式道路标注转化为mask。line_width为道路宽度(米)
#
# example数据集已经将linestrip转为mask，可以跳过这一步

# %%
img_dir = 'dataset/train/images'
geojson_dir = 'dataset/train/labels'
linestrip_to_mask.linestring_to_mask_batch(img_dir, geojson_dir, line_width=4)

# %% [markdown]
# 运行split_train_val_test程序，可将数据集划分为训练、验证、测试集。验证集测试集比例可以调整。example数据集已经将数据集划分为了train/val，可以跳过这一步

# %%
img_path = 'dataset/train/images'
label_path = 'dataset/train/labels'
split_train_val_test.split_train_val_test(img_path, label_path, val_percentage=0.1, test_percentage=0.1)

# %% [markdown]
# 运行split_image_mask_train程序，可以将大的tif图片切割成小图，方便后续识别，可以跳过这一步

# %%
# 切割尺寸（单位：米）
split_sizes = [[500, 500], [700, 700], [900, 900]]
images_folder_path = 'dataset/train/images'
masks_folder_path = 'dataset/train/labels'
# 切割后图片尺寸（和后面模型输入尺寸对应）
input_img_size = 1024
split_image_mask_train.split_images_segment_v1(images_folder_path, split_sizes, masks_folder_path, input_img_size)
# Out:
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img860.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img423.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img175.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1561.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img269.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1581.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img846.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img159.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1332.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1537.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1516.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img492.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img255.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1042.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1201.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img471.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1432.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1292.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img406.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1476.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img8.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img671.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1274.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img913.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1244.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1088.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img856.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1114.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img381.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img3.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img673.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1262.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img92.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img441.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img454.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img912.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1175.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img964.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img906.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img855.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img442.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img734.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1070.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img731.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img910.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1333.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1621.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img247.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img212.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1026.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img851.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img215.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1657.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1422.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1366.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img534.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img799.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img21.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1667.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img907.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img705.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img307.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img305.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1191.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img177.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1720.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1692.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1254.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1541.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1363.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1286.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1404.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1238.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1007.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1373.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1237.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1396.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img366.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img460.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1528.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1487.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img325.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img257.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1297.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1004.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img862.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1606.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img38.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img56.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1178.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img726.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img87.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img845.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img940.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1697.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1545.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img485.tif does not exist!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img111.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1030.tif does not exist!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1614.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1110.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1420.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1248.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1300.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1556.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1423.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1555.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1673.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img421.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1672.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img744.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img251.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1456.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img399.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img648.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img448.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1340.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1184.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img684.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1105.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img927.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img696.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img599.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1213.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img813.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img532.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1246.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img455.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1305.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img154.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img347.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1282.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img225.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img899.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1662.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img700.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1565.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1492.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1645.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img645.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1219.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img806.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1327.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img601.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img626.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img588.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img213.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1335.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img357.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img879.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1085.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1365.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1633.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1419.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1117.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img598.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1222.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1649.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img707.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1123.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img728.tif does not exist!
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img517.tif does not exist!
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1395.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1643.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img857.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img64.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1467.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img519.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img99.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img763.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img67.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img745.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img550.tif does not exist!
#
#
#
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img362.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img869.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img477.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img511.tif does not exist!
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img918.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1681.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img560.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1445.tif does not exist!
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1361.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img413.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img871.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img361.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img926.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1330.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1599.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1348.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img597.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img489.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1579.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1098.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1397.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img416.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1092.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img853.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img754.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img760.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img91.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1190.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1057.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1642.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img57.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img267.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1630.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img908.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1025.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img445.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img523.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img482.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img33.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1597.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img260.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img270.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img546.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1325.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img452.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img795.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img29.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1199.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img300.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img137.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img800.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img945.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img184.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1660.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1372.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1166.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img827.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1048.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1002.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img142.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img737.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1603.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img797.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img52.tif does not exist!
#
#
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1582.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img50.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img79.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img369.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1664.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img665.tif does not exist!
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1342.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1690.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1151.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1440.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1304.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1097.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img19.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1276.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1204.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img13.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img75.tif does not exist!
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img939.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1542.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1001.tif does not exist!
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img219.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img720.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1609.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img606.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1236.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img817.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1209.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img697.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img461.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img636.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img493.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img496.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1094.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1512.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img651.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1039.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1544.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img999.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img295.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img798.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img706.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img127.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1481.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img377.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1584.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1382.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img530.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img30.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img886.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1722.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img60.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img822.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img105.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1315.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img783.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img629.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img558.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img178.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img761.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1181.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img978.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img370.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1546.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1430.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img833.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1632.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img690.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img901.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img637.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img983.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1424.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img437.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img633.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1405.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img792.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img74.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img781.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1709.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1718.tif does not exist!
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img192.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img749.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img548.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1014.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img248.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1337.tif does not exist!
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img246.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1023.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img632.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img15.tif does not exist!
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1547.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img694.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1465.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img554.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img220.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img182.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img971.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1193.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1195.tif does not exist!
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img434.tif does not exist!
#
#
#
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1566.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1142.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img790.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img221.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1574.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1665.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img962.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img331.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img975.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img228.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1356.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1163.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1354.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img136.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1126.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1558.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1146.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1328.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1118.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1661.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img342.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1644.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img903.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img480.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1675.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1515.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img723.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img402.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1157.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img145.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img919.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img4.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1466.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1573.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img160.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1548.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1194.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1102.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img380.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1277.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img730.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img121.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1677.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img796.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img557.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img814.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img535.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1173.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img917.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img610.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1403.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img227.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1006.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img876.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1696.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1383.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1124.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1684.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1378.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1654.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img943.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img472.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img970.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img120.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1099.tif does not exist!
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1390.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1100.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img37.tif does not exist!
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img894.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img439.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img852.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img85.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1205.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img729.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1518.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1418.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img296.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img32.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img989.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img687.tif does not exist!
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1113.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img249.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1700.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1446.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1269.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1272.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img994.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img592.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1634.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img995.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img484.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1013.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img667.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1068.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img211.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1230.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img680.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img44.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img319.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1499.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img495.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1112.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img281.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img821.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img646.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img841.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img991.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img323.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1577.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1522.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img966.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img887.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1232.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1091.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1431.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1177.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img333.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img51.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1137.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img631.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1679.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1531.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1107.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1136.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img861.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img565.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1169.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img385.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1539.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img823.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1693.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1345.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img609.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img328.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img545.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1140.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1108.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img854.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img727.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img379.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img343.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1207.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img303.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1288.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1510.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1187.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img704.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1250.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img607.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img525.tif does not exist!
#
#
#
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img98.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img766.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img608.tif does not exist!
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1629.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img81.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1319.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img677.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img438.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1223.tif does not exist!
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img708.tif does not exist!
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1022.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img375.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1455.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1225.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1040.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1569.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img226.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img115.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img308.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img611.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1408.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img624.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img118.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img573.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1359.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img41.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img551.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1249.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img996.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1653.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1615.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img746.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img837.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1103.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img371.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img2.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img526.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1611.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img6.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1536.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img491.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img73.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img109.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img909.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1294.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img934.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1676.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img725.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img286.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img475.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img144.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img875.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img420.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img298.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img953.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1148.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1592.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1111.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1063.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1343.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img218.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img253.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img301.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img186.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1474.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img245.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img897.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1289.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1594.tif does not exist!
#
#
# ...
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1161.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1686.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img911.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img961.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img119.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1385.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1589.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img435.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img802.tif does not exist!
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1259.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img264.tif does not exist!
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1176.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1663.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1311.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1680.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img924.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img635.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1073.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1707.tif does not exist!
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1165.tif does not exist!
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img65.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img123.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img373.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1509.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img824.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1435.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1093.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1024.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img843.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img130.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img173.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1523.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img936.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img17.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img367.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img969.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img58.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img689.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img486.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1128.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img699.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1090.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img524.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1212.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1317.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img594.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img828.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img23.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img383.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img94.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1392.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img397.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img229.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img25.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1185.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1576.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img755.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img330.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1711.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img185.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img963.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img360.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img156.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img129.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img508.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img768.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img756.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1532.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1218.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1488.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img747.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img335.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img973.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1089.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img93.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img250.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img536.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1384.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img478.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1067.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1375.tif does not exist!
#
#
#
#
#
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img451.tif does not exist!
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img306.tif does not exist!
#
#
#
#
#
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1080.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1716.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img650.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img642.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1712.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img356.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img332.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img809.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img140.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img920.tif does not exist!
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img483.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img571.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1234.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img544.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1296.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img443.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1442.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img890.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1538.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1613.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1439.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img789.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1401.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img589.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img873.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img885.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img89.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img125.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1008.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1133.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img644.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1674.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img244.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1196.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1457.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img643.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img925.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img780.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img456.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1245.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img900.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1410.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img103.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1009.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1221.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img864.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img117.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1278.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img256.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img153.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img407.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img733.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1389.tif does not exist!
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1358.tif does not exist!
#
#
#
#
#
#
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img263.tif does not exist!
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1551.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img139.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1087.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1307.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img321.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img942.tif does not exist!
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img294.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img509.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img905.tif does not exist!
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img722.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img702.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img359.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img941.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img840.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1188.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1543.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1047.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img10.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1079.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img116.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img605.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1459.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img977.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img866.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img232.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img497.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img531.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img404.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img179.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img128.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1074.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1557.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1485.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1171.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1726.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img947.tif does not exist!
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1486.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1015.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img102.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img372.tif does not exist!
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img166.tif does not exist!
#
#
#
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1075.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img400.tif does not exist!
#
# dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img77.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1206.tif does not exist!dataset/train/labels/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img1470.tif does not exist!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Image segmentation completed!

# %% [markdown]
# ## 2. 模型训练

# %% [markdown]
# 运行train.py启动训练。训练可调参数如下。base_dir里面需要有train/val两个文件夹。

# %%
base_dir = 'dataset/'
# 模型架构可以从这几个里面选
# ['unet', 'unetplusplus', 'manet', 'linknet', 'fpn', 'pspnet', 'deeplabv3', 'deeplabv3plus', 'pan']
# https://github.com/qubvel/segmentation_models.pytorch
architecture = 'unet'

encoder = 'resnet34'
device = [0, 1, 2, 3]
save_model_every_n_epochs = 25
max_epochs = 200
checkpoint_callback_dir = os.path.join(base_dir, 'model_checkpoints/')
img_size = 640
batch_size = 8
initial_learning_rate = 1e-3
patience = 20
log_dir = os.path.join(base_dir, 'tb_logs')
# tensorboard --logdir=log_dir
# 添加本地映射命令：ssh -L 6006:localhost:6006 zkxq@192.168.50.6
name = 'access_road'

seg_data_module = train.setup_data_module(base_dir, img_size, batch_size)
model, trainer = train.setup_model_and_trainer(architecture, encoder, save_model_every_n_epochs, max_epochs,
                                         checkpoint_callback_dir, initial_learning_rate, patience,
                                         log_dir, name, device)
tuner = train.Tuner(trainer)
# Auto-scale batch size by growing it exponentially (default)
# tuner.scale_batch_size(model, mode="power")
tuner.lr_find(model, datamodule=seg_data_module)
trainer.fit(model, datamodule=seg_data_module)
valid_metrics = trainer.validate(model, seg_data_module, verbose=False)
test_metrics = trainer.test(model, seg_data_module, verbose=False)

pprint(valid_metrics)
pprint(test_metrics)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: dataset/tb_logs/access_road
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [4]
# [Epoch 0 Validation] Loss: 0.9386, IoU: 0.0309, F1: 0.0599
# Finding best initial lr:   0%|          | 0/100 [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_steps=100` reached.
# Learning rate set to 0.00478630092322638
# Restoring states from the checkpoint path at /home/zkxq/project/hjt/road_network_detection/examples/.lr_find_a04901c1-fbc8-4161-9cea-1fdd64128157.ckpt
# Restored all states from the checkpoint at /home/zkxq/project/hjt/road_network_detection/examples/.lr_find_a04901c1-fbc8-4161-9cea-1fdd64128157.ckpt
# /n[Epoch 0 Training] Loss: 0.8081, IoU: 0.1062, F1: 0.1919
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [4]
#
#   | Name    | Type     | Params
# -------------------------------------
# 0 | model   | Unet     | 24.4 M
# 1 | loss_fn | DiceLoss | 0
# -------------------------------------
# 24.4 M    Trainable params
# 0         Non-trainable params
# 24.4 M    Total params
# 97.745    Total estimated model params size (MB)
# Sanity Checking: |                                                                                          | …
# [Epoch 0 Validation] Loss: 0.9229, IoU: 0.0399, F1: 0.0767
# Training: |                                                                                                 | …
# Validation: |                                                                                               | …
# Metric val_iou improved. New best score: 0.175
# [Epoch 0 Validation] Loss: 0.7041, IoU: 0.1751, F1: 0.2966
# /n[Epoch 0 Training] Loss: 0.6290, IoU: 0.2286, F1: 0.3722
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [4]
# Validation: |                                                                                               | …
# [Epoch 1 Validation] Loss: 0.7041, IoU: 0.1751, F1: 0.2966
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [4]
# Testing: |                                                                                                  | …
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 33
#      30 valid_metrics = trainer.validate(model, seg_data_module, verbose=False)
#      31 test_metrics = trainer.test(model, seg_data_module, verbose=False)
# ---> 33 pprint(valid_metrics)
#      34 pprint(test_metrics)
#
# NameError: name 'pprint' is not defined
# Process Process-515:
# Process Process-514:
# Process Process-512:
# Process Process-522:
# Process Process-517:
# Process Process-518:
# Process Process-520:
# Exception ignored in: Process Process-525:
# Process Process-519:
# Process Process-523:
# Process Process-521:
# Process Process-516:
# Process Process-526:
# Process Process-533:
# Process Process-527:
# Process Process-528:
# Process Process-535:
# Process Process-531:
# Process Process-539:
# Process Process-529:
# Process Process-537:
# Process Process-534:
# Process Process-532:
# Process Process-530:
# Process Process-541:
# Process Process-538:
# Process Process-543:
# Process Process-545:
# Process Process-540:
# Process Process-547:
# Process Process-549:
# Process Process-551:
# Process Process-548:
# Process Process-553:
# Process Process-555:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7efe04ed1e10>Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Process-542:
# Process Process-546:
# Process Process-544:
# Process Process-552:
# Process Process-550:
# Process Process-554:
# Process Process-556:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Process-560:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Process-558:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7efe04ed1e10>Process Process-536:
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
#
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
# Traceback (most recent call last):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 307, in _bootstrap
#     self._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#       File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/context.py", line 228, in _after_fork
#     return _default_context.get_context().Process._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 68, in _after_fork
#     debug('Queue._after_fork()')
# self._shutdown_workers()  File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#       File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/synchronize.py", line 71, in _after_fork
#     def _after_fork(obj):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/synchronize.py", line 71, in _after_fork
#     def _after_fork(obj):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 342, in _after_fork
#     util._run_after_forkers()
#
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/synchronize.py", line 72, in _after_fork
#     obj._semlock._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
# self._shutdown_workers()  File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/synchronize.py", line 71, in _after_fork
#     def _after_fork(obj):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 67, in _after_fork
#     def _after_fork(self):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 76, in _reset
#     self._buffer = collections.deque()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/synchronize.py", line 72, in _after_fork
#     obj._semlock._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 68, in _after_fork
#     debug('Queue._after_fork()')
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/synchronize.py", line 71, in _after_fork
#     def _after_fork(obj):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/synchronize.py", line 72, in _after_fork
#     obj._semlock._after_fork()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/synchronize.py", line 72, in _after_fork
#     obj._semlock._after_fork()
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 167, in _run_after_forkers
#     func(obj)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 261, in _at_fork_reinit
#     self._lock._at_fork_reinit()
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/util.py", line 48, in debug
#     def debug(msg, *args):
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/synchronize.py", line 72, in _after_fork
#     obj._semlock._after_fork()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 69, in _after_fork
#     self._reset(after_fork=True)
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 76, in _reset
#     self._buffer = collections.deque()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#       File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 261, in _at_fork_reinit
#     self._lock._at_fork_reinit()
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 261, in _at_fork_reinit
#     self._lock._at_fork_reinit()
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 261, in _at_fork_reinit
#     self._lock._at_fork_reinit()
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/queues.py", line 73, in _reset
#     self._notempty._at_fork_reinit()
# if w.is_alive():KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
#       File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/threading.py", line 262, in _at_fork_reinit
#     self._waiters.clear()
# KeyboardInterrupt
#
# if w.is_alive():KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/home/zkxq/anaconda3/envs/smp/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: AssertionErrorcan only test a child process:
# can only test a child process
# [rank: 0] Received SIGTERM: 15
# [rank: 0] Received SIGTERM: 15
# [rank: 0] Received SIGTERM: 15
# [rank: 0] Received SIGTERM: 15
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 33
#      30 valid_metrics = trainer.validate(model, seg_data_module, verbose=False)
#      31 test_metrics = trainer.test(model, seg_data_module, verbose=False)
# ---> 33 pprint(valid_metrics)
#      34 pprint(test_metrics)
#
# NameError: name 'pprint' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 33
#      30 valid_metrics = trainer.validate(model, seg_data_module, verbose=False)
#      31 test_metrics = trainer.test(model, seg_data_module, verbose=False)
# ---> 33 pprint(valid_metrics)
#      34 pprint(test_metrics)
#
# NameError: name 'pprint' is not defined

# %% [markdown]
# ## 2. 模型预测

# %% [markdown]
# 运行inference.py预测模型。输入可以为图片或存放图片的文件夹

# %%
# img_path = "dataset/train/images/SN3_roads_train_AOI_4_Shanghai_PS-RGB_img10.tif"
img_dir = "dataset/train/images/"
# 切割图片大小（单位：米）
split_arr = [[300, 300], [500, 500], [700, 700]]
coordinates = []
out_dir = "dataset/out"
model_path = "dataset/model_checkpoints/best-checkpoint.ckpt"
# 单个预测或批量预测
# inference.single_predict(img_path, split_arr, model_path, out_dir, coordinates)
inference.batch_predict(img_dir, split_arr, model_path, out_dir, coordinates)

# %% [markdown]
# 运行skeleton.py，将预测的mask转换为geojson。skeleton源码来自Github，里面有很多参数可以调。

# %%
mask_dir = "dataset/out"
image_dir = "dataset/train/images/"
# Define the file prefix or suffix that your images have, if any
# For example, if your images are named like "AOI_1_grayscale.png",
# you would keep 'AOI' as the prefix.
image_prefix = 'AOI'  # Change this to match your file naming pattern

# Create a partial function that includes the directory as an argument
f = skeleton.partial(build_graph, mask_dir, image_dir)

# List all files in the directory that match the prefix condition
image_files = [filename for filename in os.listdir(mask_dir) if filename.lower().endswith('.tif')]

# Sort the list of files if necessary
image_files = sorted(image_files)

# Use multiprocessing to process all images in parallel
with skeleton.Pool() as p:
    data = skeleton.p.map(f, image_files)

# Compile all data into a list
all_data = []
out_file_path = "/home/zkxq/project/hjt/smp/geojson"
for k, v in data:
    image_path = os.path.join(image_dir, k + '.tif')
    skeleton.create_geojson(linestrings=v, image_path=image_path, out_file_path=out_file_path)
    for val in v:
        all_data.append((k, val))
